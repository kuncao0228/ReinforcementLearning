# %%
# %load_ext autoreload
# %autoreload 2

import gym

import sys
sys.path.insert(0,"PPO/")
from PPO import PPOAgent

# %%
env_name = "Pendulum-v0"
env = gym.make(env_name)


print(env.observation_space)
print(env.action_space)
# Out:
# Box(3,)
# Box(1,)

# %%
agent = PPOAgent(
    env,
    obs_dim = 3,
    act_dim = 1,
    gamma = 0.9,
    lamda = 0.95,
    entropy_coef = 0.005,
    epsilon = 0.2,
    value_range = 0.5,
    rollout_len = 4000,
    total_rollouts = 300,
    num_epochs = 30,
    batch_size = 128,
    is_evaluate = False,
    solved_reward = 0,
    plot_interval = 10,
    path2save_train_history = "trainhistory/",
)
# Out:
# device: cuda:0

# %%
agent.train()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3d92c9b1ff97> in <module>
# ----> 1 agent.train()
#
# ~/Documents/ReinforcementLearning/Networking/PPO/PPO.py in train(self)
#     180                         for _ in range(self.rollout_len):
#     181                                 action = self._get_action(state)
# --> 182                                 next_state, reward, done = self._step(action)
#     183
#     184                                 state = next_state
#
# ~/Documents/ReinforcementLearning/Networking/PPO/PPO.py in _step(self, action)
#     163                         # convert np.ndarray return from enviroment to torch tensor.
#     164                         # collect elements of trajectory.
# --> 165                         self.memory.rewards.append(torch.FloatTensor(reward).to(self.device))
#     166                         self.memory.is_terminals.append(torch.FloatTensor(1 - done).to(self.device))
#     167
#
# KeyboardInterrupt:

# %%
agent.train()

# %%
print(env.action_space.low)
# Out:
# [-2.]

# %%
import numpy as np
class PendulumActionNormalizer(gym.ActionWrapper):
    """Rescale and relocate the actions."""

    def action(self, action: np.ndarray) -> np.ndarray:
        """Change the range (-1, 1) to (low, high)."""
        low = self.action_space.low
        high = self.action_space.high

        scale_factor = (high - low) / 2
        reloc_factor = high - scale_factor

        action = action * scale_factor + reloc_factor
        action = np.clip(action, low, high)

        return action

    def reverse_action(self, action: np.ndarray) -> np.ndarray:
        """Change the range (low, high) to (-1, 1)."""
        low = self.action_space.low
        high = self.action_space.high

        scale_factor = (high - low) / 2
        reloc_factor = high - scale_factor

        action = (action - reloc_factor) / scale_factor
        action = np.clip(action, -1.0, 1.0)

        return action

# %%
env_name = "Pendulum-v0"
env = gym.make(env_name)
env = PendulumActionNormalizer(env)


print(env.observation_space)
print(env.action_space)

print(env.action_space.low)
# Out:
# Box(3,)
# Box(1,)
# [-2.]

# %%
agent = PPOAgent(
    env,
    obs_dim = 3,
    act_dim = 1,
    gamma = 0.9,
    lamda = 0.95,
    entropy_coef = 0.005,
    epsilon = 0.2,
    value_range = 0.5,
    rollout_len = 4000,
    total_rollouts = 300,
    num_epochs = 30,
    batch_size = 128,
    is_evaluate = False,
    solved_reward = 0,
    plot_interval = 10,
    path2save_train_history = "trainhistory/",
)
# Out:
# device: cuda:0

# %%
agent.train()
